# %%
#Python program to demonstrate various ways of accessing the string.
str1="welcome"
str2="DKTE"
str3="123"
print(str1)
print(str2)
print(str3)
print(str1.capitalize())
print(str1.endswith("e"))
print(str2.count("k")) #small letter
print(str2.isalpha())
print(str3.isdecimal()) #contains numbers
print(str1.isdigit()) #contains alphabets
print(str1.islower()) #all degits are lower
print(str2.isnumeric())
print(str2.isupper())
print(str1.find("e")) #returns index
print(str1.istitle()) #compulsory first letter is capital and others are small
str1=str1.replace("welcome","hello")
print(str1)
print(str1.capitalize())
print(len(str1))
print(str1.endswith("e")) #welcome = e
# Out:
# welcome
# DKTE
# 123
# Welcome
# True
# 0
# True
# True
# False
# True
# False
# True
# 1
# False
# hello
# Hello
# 5
# False
